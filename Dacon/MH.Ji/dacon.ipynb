# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import time
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torchvision.models as models
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.optim import lr_scheduler
from random import *
import os
import cv2
import copy

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    id  digit letter  0  1  2  3  4  5  6  ...  774  775  776  777  778  779  \
# 0   1      5      L  1  1  1  4  3  0  0  ...    2    1    0    1    2    4
# 1   2      0      B  0  4  0  0  4  1  1  ...    0    3    0    1    4    1
# 2   3      4      L  1  1  2  2  1  1  1  ...    3    3    3    0    2    0
# 3   4      9      D  1  2  0  2  0  4  0  ...    3    3    2    0    1    4
# 4   5      6      A  3  0  2  4  0  3  0  ...    4    4    3    2    1    3
#
#    780  781  782  783
# 0    4    4    3    4
# 1    4    2    1    2
# 2    3    0    2    2
# 3    0    0    1    1
# 4    4    3    1    2
#
# [5 rows x 787 columns]

# %%
test.head()
# Out:
#      id letter  0  1  2  3  4  5  6  7  ...  774  775  776  777  778  779  \
# 0  2049      L  0  4  0  2  4  2  3  1  ...    2    0    4    2    2    4
# 1  2050      C  4  1  4  0  1  1  0  2  ...    0    3    2    4    2    4
# 2  2051      S  0  4  0  1  3  2  3  0  ...    1    3    2    0    3    2
# 3  2052      K  2  1  3  3  3  4  3  0  ...    3    0    3    2    4    1
# 4  2053      W  1  0  1  1  2  2  1  4  ...    4    3    1    4    0    2
#
#    780  781  782  783
# 0    3    4    1    4
# 1    2    2    1    2
# 2    3    0    1    4
# 3    0    4    4    4
# 4    1    2    3    4
#
# [5 rows x 786 columns]

# %%
def make_folder(directory):
    if not os.path.isdir(directory):
        os.mkdir(directory)

path_train = os.path.join(os.getcwd(), 'emnist/train')
path_val = os.path.join(os.getcwd(), 'emnist/val')
path_test = os.path.join(os.getcwd(), 'emnist/test')

# %%
make_folder(path_train)
make_folder(path_val)
make_folder(path_test)

for i in range(10):
    path_train_digit = os.path.join(path_train, str(i))
    path_val_digit = os.path.join(path_val, str(i))
    make_folder(path_train_digit)
    make_folder(path_val_digit)

# %%
for i in range(len(train)):
    digit = train.loc[i, 'digit']
    letter = train.loc[i, 'letter']
    img = train.loc[i, '0':].values.reshape(28, 28).astype(int)

    path_train_digit = os.path.join(path_train, str(digit))
    path_val_digit = os.path.join(path_val, str(digit))
    
    if digit == 0:
        path_train_image = os.path.join(path_train_digit, '%d_%c.jpg'%(i, letter))
        path_val_image = os.path.join(path_val_digit, '%d_%c.jpg'%(i, letter))
        ran_num = randint(0,4)
        if ran_num ==0:
            cv2.imwrite(path_val_image, img)
        else:
            cv2.imwrite(path_train_image, img)
            
    elif digit == 1:
        path_train_image = os.path.join(path_train_digit, '%d_%c.jpg'%(i, letter))
        path_val_image = os.path.join(path_val_digit, '%d_%c.jpg'%(i, letter))
        ran_num = randint(0,4)
        if ran_num ==0:
            cv2.imwrite(path_val_image, img)
        else:
            cv2.imwrite(path_train_image, img)
            
    elif digit == 2:
        path_train_image = os.path.join(path_train_digit, '%d_%c.jpg'%(i, letter))
        path_val_image = os.path.join(path_val_digit, '%d_%c.jpg'%(i, letter))
        ran_num = randint(0,4)
        if ran_num ==0:
            cv2.imwrite(path_val_image, img)
        else:
            cv2.imwrite(path_train_image, img)
            
    elif digit == 3:
        path_train_image = os.path.join(path_train_digit, '%d_%c.jpg'%(i, letter))
        path_val_image = os.path.join(path_val_digit, '%d_%c.jpg'%(i, letter))
        ran_num = randint(0,4)
        if ran_num ==0:
            cv2.imwrite(path_val_image, img)
        else:
            cv2.imwrite(path_train_image, img)
            
    elif digit == 4:
        path_train_image = os.path.join(path_train_digit, '%d_%c.jpg'%(i, letter))
        path_val_image = os.path.join(path_val_digit, '%d_%c.jpg'%(i, letter))
        ran_num = randint(0,4)
        if ran_num ==0:
            cv2.imwrite(path_val_image, img)
        else:
            cv2.imwrite(path_train_image, img)
            
    elif digit == 5:
        path_train_image = os.path.join(path_train_digit, '%d_%c.jpg'%(i, letter))
        path_val_image = os.path.join(path_val_digit, '%d_%c.jpg'%(i, letter))
        ran_num = randint(0,4)
        if ran_num ==0:
            cv2.imwrite(path_val_image, img)
        else:
            cv2.imwrite(path_train_image, img)
        
    elif digit == 6:
        path_train_image = os.path.join(path_train_digit, '%d_%c.jpg'%(i, letter))
        path_val_image = os.path.join(path_val_digit, '%d_%c.jpg'%(i, letter))
        ran_num = randint(0,4)
        if ran_num ==0:
            cv2.imwrite(path_val_image, img)
        else:
            cv2.imwrite(path_train_image, img)
            
    elif digit == 7:
        path_train_image = os.path.join(path_train_digit, '%d_%c.jpg'%(i, letter))
        path_val_image = os.path.join(path_val_digit, '%d_%c.jpg'%(i, letter))
        ran_num = randint(0,4)
        if ran_num ==0:
            cv2.imwrite(path_val_image, img)
        else:
            cv2.imwrite(path_train_image, img)
            
    elif digit == 8:
        path_train_image = os.path.join(path_train_digit, '%d_%c.jpg'%(i, letter))
        path_val_image = os.path.join(path_val_digit, '%d_%c.jpg'%(i, letter))
        ran_num = randint(0,4)
        if ran_num ==0:
            cv2.imwrite(path_val_image, img)
        else:
            cv2.imwrite(path_train_image, img)
            
    elif digit == 9:
        path_train_image = os.path.join(path_train_digit, '%d_%c.jpg'%(i, letter))
        path_val_image = os.path.join(path_val_digit, '%d_%c.jpg'%(i, letter))
        ran_num = randint(0,4)
        if ran_num ==0:
            cv2.imwrite(path_val_image, img)
        else:
            cv2.imwrite(path_train_image, img)

# %%
for i in range(len(test)):
    letter = test.loc[i, 'letter']
    img = test.loc[i, '0':].values.reshape(28, 28).astype(int)
    
    path_test_digit = os.path.join(path_test, '%d_%c.jpg'%(i, letter))
    cv2.imwrite(path_test_digit, img)

# %% [markdown]
# ### 데이터셋

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(30),
        transforms.RandomHorizontalFlip(),
        transforms.Grayscale(num_output_channels=1),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ]),
    'val': transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.Grayscale(num_output_channels=1),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])
}

# %%
data_dir = os.path.join(os.getcwd(), 'emnist')
image_datasets = {x: dset.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16, shuffle=True, num_workers=4) for x in ['train', 'val']}

# %%
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

# %%
class customCNN(nn.Module):
    def __init__(self):
        super(customCNN, self).__init__()
        
        self.layer1 = self.conv_module(1, 16)
        self.layer3 = self.conv_module(16, 24)
        self.layer4 = self.conv_module(24, 32)
        self.layer5 = self.conv_module(32, 64)
        self.layer6 = self.conv_module(64,128)
        self.gap = self.global_avg_pool(128, 10)
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.layer6(out)
        out = self.gap(out)
        out = out.view(-1, 10)

        return out
    
    def conv_module(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=3, stride=1)
        )
    
    def global_avg_pool(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.AdaptiveAvgPool2d((1, 1))
        )

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
model = customCNN()
model = model.to(device)
print(model)
# Out:
# customCNN(
#   (layer1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): MaxPool2d(kernel_size=3, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(16, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): MaxPool2d(kernel_size=3, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer4): Sequential(
#     (0): Conv2d(24, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): MaxPool2d(kernel_size=3, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer5): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): MaxPool2d(kernel_size=3, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer6): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): MaxPool2d(kernel_size=3, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (gap): Sequential(
#     (0): Conv2d(128, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
exp_lr_scheduler = lr_scheduler.ReduceLROnPlateau(optimizer_ft, factor=0.1, patience=5)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=8):


    global_info = []
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    early_stopping = EarlyStopping(patience=11, verbose=True)
    for epoch in range(num_epochs):
        local_info = []
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':

                model.train()  # Set model to training mode
            else:

                model.eval()   # Set model to evaluate mode
                if epoch >0:
                    scheduler.step(val_loss)
            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            if phase == 'val':
                val_loss = running_loss / dataset_sizes['val']
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            #(Variable(x).data).cpu().numpy()
            if phase == 'train':
                local_info.append(epoch_loss)
                ea = epoch_acc.cpu().numpy()
                local_info.append(ea)
            else:
                local_info.append(epoch_loss)
                ea = epoch_acc.cpu().numpy()
                local_info.append(ea)



            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
        lr_get = get_lr(optimizer)
        print("Current learning rate : {:.8f}".format(lr_get))
        global_info.append(local_info)
        if phase =='val':
            early_stopping(epoch_loss, model)

            if early_stopping.early_stop:
                print("Early stopping")
                break

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']
    
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
model_ft = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 2.2481 Acc: 0.1636
# val Loss: 2.2004 Acc: 0.1805
# Current learning rate : 0.00100000
# Validation loss decreased (inf --> 2.200381).  Saving model ...
# Epoch 1/99
# ----------
# train Loss: 2.1887 Acc: 0.2082
# val Loss: 2.1507 Acc: 0.2780
# Current learning rate : 0.00100000
# Validation loss decreased (2.200381 --> 2.150661).  Saving model ...
# Epoch 2/99
# ----------
# train Loss: 2.1612 Acc: 0.2326
# val Loss: 2.1175 Acc: 0.2732
# Current learning rate : 0.00100000
# Validation loss decreased (2.150661 --> 2.117491).  Saving model ...
# Epoch 3/99
# ----------
# train Loss: 2.1246 Acc: 0.2814
# val Loss: 2.0810 Acc: 0.3073
# Current learning rate : 0.00100000
# Validation loss decreased (2.117491 --> 2.080970).  Saving model ...
# Epoch 4/99
# ----------
# train Loss: 2.1057 Acc: 0.2875
# val Loss: 2.0324 Acc: 0.3024
# Current learning rate : 0.00100000
# Validation loss decreased (2.080970 --> 2.032380).  Saving model ...
# Epoch 5/99
# ----------
# train Loss: 2.0820 Acc: 0.3016
# val Loss: 2.0554 Acc: 0.2878
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 6/99
# ----------
# train Loss: 2.0660 Acc: 0.3016
# val Loss: 1.9997 Acc: 0.2878
# Current learning rate : 0.00100000
# Validation loss decreased (2.032380 --> 1.999657).  Saving model ...
# Epoch 7/99
# ----------
# train Loss: 2.0474 Acc: 0.3254
# val Loss: 1.9926 Acc: 0.2683
# Current learning rate : 0.00100000
# Validation loss decreased (1.999657 --> 1.992579).  Saving model ...
# Epoch 8/99
# ----------
# train Loss: 2.0344 Acc: 0.3236
# val Loss: 1.9939 Acc: 0.3390
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 9/99
# ----------
# train Loss: 2.0101 Acc: 0.3407
# val Loss: 1.9591 Acc: 0.3366
# Current learning rate : 0.00100000
# Validation loss decreased (1.992579 --> 1.959114).  Saving model ...
# Epoch 10/99
# ----------
# train Loss: 1.9930 Acc: 0.3767
# val Loss: 1.9889 Acc: 0.3098
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 11/99
# ----------
# train Loss: 1.9875 Acc: 0.3596
# val Loss: 1.9177 Acc: 0.3488
# Current learning rate : 0.00100000
# Validation loss decreased (1.959114 --> 1.917741).  Saving model ...
# Epoch 12/99
# ----------
# train Loss: 1.9541 Acc: 0.3547
# val Loss: 1.8511 Acc: 0.4244
# Current learning rate : 0.00100000
# Validation loss decreased (1.917741 --> 1.851139).  Saving model ...
# Epoch 13/99
# ----------
# train Loss: 1.9354 Acc: 0.3748
# val Loss: 1.9566 Acc: 0.3171
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 14/99
# ----------
# train Loss: 1.9381 Acc: 0.3736
# val Loss: 1.8710 Acc: 0.4098
# Current learning rate : 0.00100000
# EarlyStopping counter: 2 out of 11
# Epoch 15/99
# ----------
# train Loss: 1.9091 Acc: 0.3926
# val Loss: 1.8808 Acc: 0.3610
# Current learning rate : 0.00100000
# EarlyStopping counter: 3 out of 11
# Epoch 16/99
# ----------
# train Loss: 1.9145 Acc: 0.3846
# val Loss: 1.8172 Acc: 0.4098
# Current learning rate : 0.00100000
# Validation loss decreased (1.851139 --> 1.817175).  Saving model ...
# Epoch 17/99
# ----------
# train Loss: 1.8789 Acc: 0.4029
# val Loss: 1.8097 Acc: 0.4244
# Current learning rate : 0.00100000
# Validation loss decreased (1.817175 --> 1.809680).  Saving model ...
# Epoch 18/99
# ----------
# train Loss: 1.8626 Acc: 0.4084
# val Loss: 1.8481 Acc: 0.3366
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 19/99
# ----------
# train Loss: 1.8437 Acc: 0.4194
# val Loss: 1.7869 Acc: 0.4220
# Current learning rate : 0.00100000
# Validation loss decreased (1.809680 --> 1.786866).  Saving model ...
# Epoch 20/99
# ----------
# train Loss: 1.8300 Acc: 0.4115
# val Loss: 1.7571 Acc: 0.4171
# Current learning rate : 0.00100000
# Validation loss decreased (1.786866 --> 1.757073).  Saving model ...
# Epoch 21/99
# ----------
# train Loss: 1.8119 Acc: 0.4457
# val Loss: 1.7384 Acc: 0.4439
# Current learning rate : 0.00100000
# Validation loss decreased (1.757073 --> 1.738444).  Saving model ...
# Epoch 22/99
# ----------
# train Loss: 1.8150 Acc: 0.4292
# val Loss: 1.7665 Acc: 0.3878
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 23/99
# ----------
# train Loss: 1.7747 Acc: 0.4512
# val Loss: 1.7005 Acc: 0.4634
# Current learning rate : 0.00100000
# Validation loss decreased (1.738444 --> 1.700504).  Saving model ...
# Epoch 24/99
# ----------
# train Loss: 1.7648 Acc: 0.4420
# val Loss: 1.6423 Acc: 0.5293
# Current learning rate : 0.00100000
# Validation loss decreased (1.700504 --> 1.642349).  Saving model ...
# Epoch 25/99
# ----------
# train Loss: 1.7505 Acc: 0.4560
# val Loss: 1.7385 Acc: 0.4244
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 26/99
# ----------
# train Loss: 1.7305 Acc: 0.4731
# val Loss: 1.6764 Acc: 0.5024
# Current learning rate : 0.00100000
# EarlyStopping counter: 2 out of 11
# Epoch 27/99
# ----------
# train Loss: 1.7269 Acc: 0.4640
# val Loss: 1.6733 Acc: 0.4732
# Current learning rate : 0.00100000
# EarlyStopping counter: 3 out of 11
# Epoch 28/99
# ----------
# train Loss: 1.6923 Acc: 0.4872
# val Loss: 1.5781 Acc: 0.5073
# Current learning rate : 0.00100000
# Validation loss decreased (1.642349 --> 1.578077).  Saving model ...
# Epoch 29/99
# ----------
# train Loss: 1.6807 Acc: 0.4841
# val Loss: 1.5969 Acc: 0.5195
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 30/99
# ----------
# train Loss: 1.6721 Acc: 0.4969
# val Loss: 1.5596 Acc: 0.5415
# Current learning rate : 0.00100000
# Validation loss decreased (1.578077 --> 1.559617).  Saving model ...
# Epoch 31/99
# ----------
# train Loss: 1.6373 Acc: 0.5122
# val Loss: 1.5956 Acc: 0.4537
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 32/99
# ----------
# train Loss: 1.6397 Acc: 0.4908
# val Loss: 1.5319 Acc: 0.5439
# Current learning rate : 0.00100000
# Validation loss decreased (1.559617 --> 1.531880).  Saving model ...
# Epoch 33/99
# ----------
# train Loss: 1.6275 Acc: 0.5055
# val Loss: 1.5310 Acc: 0.4951
# Current learning rate : 0.00100000
# Validation loss decreased (1.531880 --> 1.530975).  Saving model ...
# Epoch 34/99
# ----------
# train Loss: 1.6021 Acc: 0.5208
# val Loss: 1.5595 Acc: 0.4805
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 35/99
# ----------
# train Loss: 1.6050 Acc: 0.5177
# val Loss: 1.5090 Acc: 0.5268
# Current learning rate : 0.00100000
# Validation loss decreased (1.530975 --> 1.509042).  Saving model ...
# Epoch 36/99
# ----------
# train Loss: 1.5940 Acc: 0.5037
# val Loss: 1.5163 Acc: 0.5098
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 37/99
# ----------
# train Loss: 1.5869 Acc: 0.5049
# val Loss: 1.4696 Acc: 0.5366
# Current learning rate : 0.00100000
# Validation loss decreased (1.509042 --> 1.469628).  Saving model ...
# Epoch 38/99
# ----------
# train Loss: 1.5443 Acc: 0.5525
# val Loss: 1.5404 Acc: 0.4829
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 39/99
# ----------
# train Loss: 1.5305 Acc: 0.5366
# val Loss: 1.4636 Acc: 0.5049
# Current learning rate : 0.00100000
# Validation loss decreased (1.469628 --> 1.463571).  Saving model ...
# Epoch 40/99
# ----------
# train Loss: 1.5186 Acc: 0.5305
# val Loss: 1.4769 Acc: 0.5049
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 41/99
# ----------
# train Loss: 1.5154 Acc: 0.5482
# val Loss: 1.4234 Acc: 0.5756
# Current learning rate : 0.00100000
# Validation loss decreased (1.463571 --> 1.423404).  Saving model ...
# Epoch 42/99
# ----------
# train Loss: 1.4857 Acc: 0.5476
# val Loss: 1.4053 Acc: 0.5634
# Current learning rate : 0.00100000
# Validation loss decreased (1.423404 --> 1.405319).  Saving model ...
# Epoch 43/99
# ----------
# train Loss: 1.5049 Acc: 0.5556
# val Loss: 1.4996 Acc: 0.5366
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 44/99
# ----------
# train Loss: 1.4993 Acc: 0.5415
# val Loss: 1.4179 Acc: 0.5293
# Current learning rate : 0.00100000
# EarlyStopping counter: 2 out of 11
# Epoch 45/99
# ----------
# train Loss: 1.4737 Acc: 0.5684
# val Loss: 1.3789 Acc: 0.5683
# Current learning rate : 0.00100000
# Validation loss decreased (1.405319 --> 1.378868).  Saving model ...
# Epoch 46/99
# ----------
# train Loss: 1.4451 Acc: 0.5653
# val Loss: 1.4231 Acc: 0.5195
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 47/99
# ----------
# train Loss: 1.4658 Acc: 0.5598
# val Loss: 1.3946 Acc: 0.5390
# Current learning rate : 0.00100000
# EarlyStopping counter: 2 out of 11
# Epoch 48/99
# ----------
# train Loss: 1.4167 Acc: 0.5824
# val Loss: 1.3865 Acc: 0.5756
# Current learning rate : 0.00100000
# EarlyStopping counter: 3 out of 11
# Epoch 49/99
# ----------
# train Loss: 1.4334 Acc: 0.5659
# val Loss: 1.3959 Acc: 0.5634
# Current learning rate : 0.00100000
# EarlyStopping counter: 4 out of 11
# Epoch 50/99
# ----------
# train Loss: 1.4139 Acc: 0.5769
# val Loss: 1.3900 Acc: 0.5756
# Current learning rate : 0.00100000
# EarlyStopping counter: 5 out of 11
# Epoch 51/99
# ----------
# train Loss: 1.3973 Acc: 0.5873
# val Loss: 1.3202 Acc: 0.5732
# Current learning rate : 0.00100000
# Validation loss decreased (1.378868 --> 1.320217).  Saving model ...
# Epoch 52/99
# ----------
# train Loss: 1.3840 Acc: 0.6044
# val Loss: 1.3426 Acc: 0.5902
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 53/99
# ----------
# train Loss: 1.3749 Acc: 0.5934
# val Loss: 1.3132 Acc: 0.6073
# Current learning rate : 0.00100000
# Validation loss decreased (1.320217 --> 1.313208).  Saving model ...
# Epoch 54/99
# ----------
# train Loss: 1.3733 Acc: 0.5977
# val Loss: 1.3423 Acc: 0.5829
# Current learning rate : 0.00100000
# EarlyStopping counter: 1 out of 11
# Epoch 55/99
# ----------
# train Loss: 1.3497 Acc: 0.6111
# val Loss: 1.3512 Acc: 0.5561
# Current learning rate : 0.00100000
# EarlyStopping counter: 2 out of 11
# Epoch 56/99
# ----------
# train Loss: 1.3329 Acc: 0.6093
# val Loss: 1.3349 Acc: 0.5561
# Current learning rate : 0.00100000
# EarlyStopping counter: 3 out of 11
# Epoch 57/99
# ----------
# train Loss: 1.3246 Acc: 0.6160
# val Loss: 1.3816 Acc: 0.5366
# Current learning rate : 0.00100000
# EarlyStopping counter: 4 out of 11
# Epoch 58/99
# ----------
# train Loss: 1.3136 Acc: 0.6203
# val Loss: 1.3311 Acc: 0.5756
# Current learning rate : 0.00100000
# EarlyStopping counter: 5 out of 11
# Epoch 59/99
# ----------
# train Loss: 1.3219 Acc: 0.6160
# val Loss: 1.3308 Acc: 0.5683
# Current learning rate : 0.00100000
# EarlyStopping counter: 6 out of 11
# Epoch 60/99
# ----------
# train Loss: 1.2977 Acc: 0.6013
# val Loss: 1.3316 Acc: 0.5707
# Current learning rate : 0.00010000
# EarlyStopping counter: 7 out of 11
# Epoch 61/99
# ----------
# train Loss: 1.2339 Acc: 0.6600
# val Loss: 1.1616 Acc: 0.6439
# Current learning rate : 0.00010000
# Validation loss decreased (1.313208 --> 1.161571).  Saving model ...
# Epoch 62/99
# ----------
# train Loss: 1.2282 Acc: 0.6532
# val Loss: 1.1800 Acc: 0.6537
# Current learning rate : 0.00010000
# EarlyStopping counter: 1 out of 11
# Epoch 63/99
# ----------
# train Loss: 1.2141 Acc: 0.6477
# val Loss: 1.1573 Acc: 0.6756
# Current learning rate : 0.00010000
# Validation loss decreased (1.161571 --> 1.157338).  Saving model ...
# Epoch 64/99
# ----------
# train Loss: 1.1941 Acc: 0.6722
# val Loss: 1.1301 Acc: 0.6610
# Current learning rate : 0.00010000
# Validation loss decreased (1.157338 --> 1.130085).  Saving model ...
# Epoch 65/99
# ----------
# train Loss: 1.1736 Acc: 0.6722
# val Loss: 1.1626 Acc: 0.6463
# Current learning rate : 0.00010000
# EarlyStopping counter: 1 out of 11
# Epoch 66/99
# ----------
# train Loss: 1.1946 Acc: 0.6575
# val Loss: 1.1431 Acc: 0.6732
# Current learning rate : 0.00010000
# EarlyStopping counter: 2 out of 11
# Epoch 67/99
# ----------
# train Loss: 1.1918 Acc: 0.6679
# val Loss: 1.1301 Acc: 0.6561
# Current learning rate : 0.00010000
# EarlyStopping counter: 3 out of 11
# Epoch 68/99
# ----------
# train Loss: 1.1844 Acc: 0.6716
# val Loss: 1.1381 Acc: 0.6683
# Current learning rate : 0.00010000
# EarlyStopping counter: 4 out of 11
# Epoch 69/99
# ----------
# train Loss: 1.1828 Acc: 0.6746
# val Loss: 1.1290 Acc: 0.6561
# Current learning rate : 0.00010000
# Validation loss decreased (1.130085 --> 1.128979).  Saving model ...
# Epoch 70/99
# ----------
# train Loss: 1.1552 Acc: 0.6856
# val Loss: 1.1319 Acc: 0.6610
# Current learning rate : 0.00010000
# EarlyStopping counter: 1 out of 11
# Epoch 71/99
# ----------
# train Loss: 1.1820 Acc: 0.6722
# val Loss: 1.1321 Acc: 0.6634
# Current learning rate : 0.00010000
# EarlyStopping counter: 2 out of 11
# Epoch 72/99
# ----------
# train Loss: 1.1688 Acc: 0.6905
# val Loss: 1.1568 Acc: 0.6317
# Current learning rate : 0.00010000
# EarlyStopping counter: 3 out of 11
# Epoch 73/99
# ----------
# train Loss: 1.1753 Acc: 0.6777
# val Loss: 1.1338 Acc: 0.6634
# Current learning rate : 0.00010000
# EarlyStopping counter: 4 out of 11
# Epoch 74/99
# ----------
# train Loss: 1.1455 Acc: 0.6984
# val Loss: 1.1157 Acc: 0.6683
# Current learning rate : 0.00010000
# Validation loss decreased (1.128979 --> 1.115663).  Saving model ...
# Epoch 75/99
# ----------
# train Loss: 1.1634 Acc: 0.6929
# val Loss: 1.1522 Acc: 0.6463
# Current learning rate : 0.00010000
# EarlyStopping counter: 1 out of 11
# Epoch 76/99
# ----------
# train Loss: 1.1540 Acc: 0.6911
# val Loss: 1.1488 Acc: 0.6390
# Current learning rate : 0.00010000
# EarlyStopping counter: 2 out of 11
# Epoch 77/99
# ----------
# train Loss: 1.1705 Acc: 0.6801
# val Loss: 1.1278 Acc: 0.6610
# Current learning rate : 0.00010000
# EarlyStopping counter: 3 out of 11
# Epoch 78/99
# ----------
# train Loss: 1.1566 Acc: 0.6832
# val Loss: 1.1250 Acc: 0.6951
# Current learning rate : 0.00010000
# EarlyStopping counter: 4 out of 11
# Epoch 79/99
# ----------
# train Loss: 1.1775 Acc: 0.6636
# val Loss: 1.1251 Acc: 0.6439
# Current learning rate : 0.00010000
# EarlyStopping counter: 5 out of 11
# Epoch 80/99
# ----------
# train Loss: 1.1461 Acc: 0.6923
# val Loss: 1.1228 Acc: 0.6829
# Current learning rate : 0.00010000
# EarlyStopping counter: 6 out of 11
# Epoch 81/99
# ----------
# train Loss: 1.1456 Acc: 0.6862
# val Loss: 1.1051 Acc: 0.6732
# Current learning rate : 0.00001000
# Validation loss decreased (1.115663 --> 1.105099).  Saving model ...
# Epoch 82/99
# ----------
# train Loss: 1.1377 Acc: 0.6923
# val Loss: 1.0999 Acc: 0.6683
# Current learning rate : 0.00001000
# Validation loss decreased (1.105099 --> 1.099879).  Saving model ...
# Epoch 83/99
# ----------
# train Loss: 1.1366 Acc: 0.6929
# val Loss: 1.1084 Acc: 0.6683
# Current learning rate : 0.00001000
# EarlyStopping counter: 1 out of 11
# Epoch 84/99
# ----------
# train Loss: 1.1451 Acc: 0.6929
# val Loss: 1.1207 Acc: 0.6585
# Current learning rate : 0.00001000
# EarlyStopping counter: 2 out of 11
# Epoch 85/99
# ----------
# train Loss: 1.1604 Acc: 0.6801
# val Loss: 1.1303 Acc: 0.6659
# Current learning rate : 0.00001000
# EarlyStopping counter: 3 out of 11
# Epoch 86/99
# ----------
# train Loss: 1.1271 Acc: 0.7027
# val Loss: 1.1230 Acc: 0.6659
# Current learning rate : 0.00001000
# EarlyStopping counter: 4 out of 11
# Epoch 87/99
# ----------
# train Loss: 1.1438 Acc: 0.6844
# val Loss: 1.1183 Acc: 0.6610
# Current learning rate : 0.00001000
# EarlyStopping counter: 5 out of 11
# Epoch 88/99
# ----------
# train Loss: 1.1235 Acc: 0.7070
# val Loss: 1.1117 Acc: 0.6707
# Current learning rate : 0.00001000
# EarlyStopping counter: 6 out of 11
# Epoch 89/99
# ----------
# train Loss: 1.1230 Acc: 0.7118
# val Loss: 1.1087 Acc: 0.6561
# Current learning rate : 0.00000100
# EarlyStopping counter: 7 out of 11
# Epoch 90/99
# ----------
# train Loss: 1.1455 Acc: 0.6899
# val Loss: 1.1364 Acc: 0.6390
# Current learning rate : 0.00000100
# EarlyStopping counter: 8 out of 11
# Epoch 91/99
# ----------
# train Loss: 1.1441 Acc: 0.6813
# val Loss: 1.1092 Acc: 0.6537
# Current learning rate : 0.00000100
# EarlyStopping counter: 9 out of 11
# Epoch 92/99
# ----------
# train Loss: 1.1421 Acc: 0.6917
# val Loss: 1.1151 Acc: 0.6659
# Current learning rate : 0.00000100
# EarlyStopping counter: 10 out of 11
# Epoch 93/99
# ----------
# train Loss: 1.1424 Acc: 0.6935
# val Loss: 1.0949 Acc: 0.6805
# Current learning rate : 0.00000100
# Validation loss decreased (1.099879 --> 1.094896).  Saving model ...
# Epoch 94/99
# ----------
# train Loss: 1.1490 Acc: 0.6874
# val Loss: 1.1159 Acc: 0.6585
# Current learning rate : 0.00000100
# EarlyStopping counter: 1 out of 11
# Epoch 95/99
# ----------
# train Loss: 1.1478 Acc: 0.6838
# val Loss: 1.1286 Acc: 0.6634
# Current learning rate : 0.00000100
# EarlyStopping counter: 2 out of 11
# Epoch 96/99
# ----------
# train Loss: 1.1340 Acc: 0.7033
# val Loss: 1.1087 Acc: 0.6732
# Current learning rate : 0.00000100
# EarlyStopping counter: 3 out of 11
# Epoch 97/99
# ----------
# train Loss: 1.1372 Acc: 0.6807
# val Loss: 1.1150 Acc: 0.6854
# Current learning rate : 0.00000100
# EarlyStopping counter: 4 out of 11
# Epoch 98/99
# ----------
# train Loss: 1.1541 Acc: 0.6819
# val Loss: 1.1090 Acc: 0.6756
# Current learning rate : 0.00000100
# EarlyStopping counter: 5 out of 11
# Epoch 99/99
# ----------
# train Loss: 1.1395 Acc: 0.6825
# val Loss: 1.1062 Acc: 0.6976
# Current learning rate : 0.00000100
# EarlyStopping counter: 6 out of 11
# Training complete in 1m 19s
# Best val Acc: 0.697561

# %%
torch.save(model, './model/emnist_model1.pt')

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model(model_ft)

# %%
import natsort as nt
from PIL import Image
from torch.autograd import Variable 

def test_model():
    data_transforms = transforms.Compose([
        transforms.Grayscale(num_output_channels=1),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])
    model_ft = torch.load('./model/emnist_model1.pt', map_location=device)
    path_test = os.path.join(os.getcwd(), 'emnist/test')
    image_list = nt.natsorted(os.listdir(path_test))
    output_list = []
    for i, images in enumerate(image_list):
        path_test_image = os.path.join(path_test, images)
        image = Image.open(path_test_image)
        image = data_transforms(image)
        image.unsqueeze_(dim=0)
        image = Variable(image)
        image = image.cuda(device)
        torch.no_grad()
        output = model(image)
        output = torch.argmax(output, dim=1)
        output_list.append(output)
        
    return output_list

output = test_model()

# %%
submission = pd.read_csv('submission.csv')
submission.digit = torch.cat(output).detach().cpu().numpy()
submission.to_csv('./result/submission1.csv', index=False)

# %%
submission
# Out:
#           id  digit
# 0       2049      6
# 1       2050      0
# 2       2051      6
# 3       2052      0
# 4       2053      3
# ...      ...    ...
# 20475  22524      4
# 20476  22525      1
# 20477  22526      6
# 20478  22527      1
# 20479  22528      0
#
# [20480 rows x 2 columns]
